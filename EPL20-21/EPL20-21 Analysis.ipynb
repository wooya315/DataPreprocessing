# %% [markdown]
# ## English Premier League(2020-21) 데이터 전처리 및 시각화

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# csv 파일 불러오기

# %%
df = pd.read_csv("./EPL_20_21.csv")

# %%
df.shape #532개 데이터와 18개 column이 있다는 것을 확인
# Out:
# (532, 18)

# %% [markdown]
# 우선 데이터 5개를 뽑아서 어떻게 생겼는지 확인해보자.

# %%
df.head(5)
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %% [markdown]
# 마지막 데이터 확인하는 방법

# %%
df.tail(5)
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 527       2   296      0        0                50                   80.0
# 528       2   180      0        0                77                   77.9
# 529       0    12      0        0                 3                  100.0
# 530       0    11      0        0                 1                  100.0
# 531       0     1      0        0                 0                   -1.0
#
# ...

# %%
df.drop_duplicates(['Club'])
# Out:
#                   Name                     Club Nationality Position  Age  \
# 0          Mason Mount                  Chelsea         ENG    MF,FW   21
# 27             Ederson          Manchester City         BRA       GK   26
# 51     Bruno Fernandes        Manchester United         POR       MF   25
# 80    Andrew Robertson             Liverpool FC         SCO       DF   26
# 108  Kasper Schmeichel           Leicester City         DEN       GK   33
# 135       Tomáš Souček          West Ham United         CZE       MF   25
# 159    Pierre Højbjerg        Tottenham Hotspur         DEN       MF   24
# 183         Bernd Leno                  Arsenal         GER       GK   28
# 212      Stuart Dallas             Leeds United         NIR    DF,MF   29
# 235      Michael Keane                  Everton         ENG       DF   27
# 264  Emiliano Martínez              Aston Villa         ARG       GK   27
# 288      Jonjo Shelvey         Newcastle United         ENG       MF   28
# ...

# %%
is_Sheffield_United = df['Club'] == 'Sheffield United'
Sheffield_United = df[is_Sheffield_United]
print(len(Sheffield_United))
# Out:
# 27

# %%
is_Chelsea = df['Club'] == 'Chelsea'
Chelsea = df[is_Chelsea]
print(len(Chelsea))
# Out:
# 27

# %%
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 527     True
# 528     True
# 529     True
# 530     True
# 531     True
# Length: 532, dtype: bool
